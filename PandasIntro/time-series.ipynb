# %%
import numpy as np
import pandas as pd

# %%
rng = pd.date_range("1/1/2024", periods=100, freq="s")
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample("5Min").sum()
# Out:
# 2024-01-01    23441
# Freq: 5min, dtype: int64

# %%
rng = pd.date_range("3/6/2023 00:00", periods=5, freq="D")
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2023-03-06    0.937155
# 2023-03-07   -1.509124
# 2023-03-08   -0.109434
# 2023-03-09    0.558524
# 2023-03-10   -1.782499
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")
ts_utc
# Out:
# 2023-03-06 00:00:00+00:00    0.937155
# 2023-03-07 00:00:00+00:00   -1.509124
# 2023-03-08 00:00:00+00:00   -0.109434
# 2023-03-09 00:00:00+00:00    0.558524
# 2023-03-10 00:00:00+00:00   -1.782499
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2023-03-05 19:00:00-05:00    0.937155
# 2023-03-06 19:00:00-05:00   -1.509124
# 2023-03-07 19:00:00-05:00   -0.109434
# 2023-03-08 19:00:00-05:00    0.558524
# 2023-03-09 19:00:00-05:00   -1.782499
# Freq: D, dtype: float64

# %%
rng
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2023-03-13', '2023-03-14', '2023-03-15', '2023-03-16',
#                '2023-03-17'],
#               dtype='datetime64[ns]', freq=None)
